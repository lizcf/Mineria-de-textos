# %%
import codecs
import json, string, math
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sb  
import operator

import numpy as np
import re
from collections import Counter
from __future__ import division
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from random import randint
import datetime

np.random.seed(50)

# %%
def remove_punctuation (text):
    return text.translate(None, string.punctuation)

def fix_encoding(s):
    return s.decode('utf8', 'ignore')

def text_to_words(text):
    words_only = re.sub("[^a-zA-Z]"," ",text.split())
    return words_only

def words_to_word(words):
    dictionary={}
    words = words.split()
    for i in range(len(words)):
        #if words[i] not in stopwords.words('spanish'):
        if not dictionary.has_key(words[i]):
            dictionary[words[i]]=words[i]
    return dictionary

def create_matrix(m,n,aleatory):
    maxdim = 0
    if (m>n) or (m==n) :
        maxdim = m
    else:
        maxdim = n
    if aleatory==True:
        matrix =[[randint(-maxdim, maxdim) for i in range(m)] for i in range(n)]
    else:
        matrix =[[0. for i in range(m)] for i in range(n)]
    return matrix

def error_function():
#negative sampling    
    return

def distance_function():
#tanh
    return

def order_dictionary(dictionary):
    dictionarysorted =  sorted(dictionary)
    return dictionarysorted
    
def open_file(pathfile):
    with codecs.open(pathfile,'r') as f: # Abrimos el archivo
        data = f.read()
        f.close()
    return data

def make_graphic(Matrix, dictionary):
    # %matplotlib inline
    plt.plot(Matrix[:,0], Matrix[:,1], 'o')  
    for word, x, y in zip(dictionary, Matrix[:,0], Matrix[:,1]):  
        plt.annotate(word, (x, y), size=12)
    return plt.show()

# %%
dWords={}
lContextos =[]
tCorpus = 0

corpus =  remove_punctuation(open_file('corpus_WE.txt'))
corpusfix = fix_encoding(corpus.lower())
    
dWords= words_to_word(corpusfix)
lContextos =  corpusfix.splitlines()
tCorpus= len(dWords.keys())

# %%
tCorpus
# Out:
# 3389

# %%
W=  (np.random.random((tCorpus, 2)) - 0.5) / 2
V = (np.random.random((2, tCorpus)) - 0.5) / tCorpus
WI = W

W=np.array(W)
V=np.array(V)
V = np.transpose(V)

make_graphic(W,dWords)
dWords = order_dictionary(dWords)

# %%
h = [0.0,0.0]
Z=0.0
learning_factor = 0.1

start_time = datetime.datetime.now()

for i in range(50):
    for c in lContextos: #Recorre el contexto
        #Promedio de las palabras del contexto
        h= (sum(W[dWords.index(wC)] for wC in c.split()))/len(c) 
        #Promedio del < > del corpus vs promedio del contexto
        Z= (sum(np.exp(np.tanh((-np.dot(V[dWords.index(w)], h)))) for w in dWords)) 
        for w in dWords: #Recorre el diccionario    
            Pw_c = np.exp(np.tanh((-np.dot(W[dWords.index(w)], h)))) / Z
            if w in c:
                V[dWords.index(w)]  = V[dWords.index(w)] - (learning_factor*(1 -Pw_c)*h)
            else:
                V[dWords.index(w)]  = V[dWords.index(w)] - (learning_factor*(0 -Pw_c)*h)      
        h = [0.0,0.0] #Reinicio variables
        Z=0.0

    MeanV= (sum(V[dWords.index(w)] for w in dWords))/len(dWords) #Promedio del vector V
    for c in lContextos: #Recorre el contexto
        for w in dWords: #Recorre el diccionario
            if w in c:
                W[dWords.index(w)] = W[dWords.index(w)] - learning_factor*MeanV
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 970, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 233, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 267, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Liz Contreras\Anaconda\lib\inspect.py", line 1044, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "C:\Users\Liz Contreras\Anaconda\lib\inspect.py", line 1008, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 171, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "C:\Users\Liz Contreras\Anaconda\lib\linecache.py", line 41, in getlines
#     return updatecache(filename, module_globals)
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#   File "C:\Users\Liz Contreras\Anaconda\lib\linecache.py", line 131, in updatecache
#     with open(fullname, 'rU') as fp:
# KeyboardInterrupt
# Unfortunately, your original traceback can not be constructed.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\interactiveshell.pyc in run_code(self, code_obj, result)
#    3050             if result is not None:
#    3051                 result.error_in_exec = sys.exc_info()[1]
# -> 3052             self.showtraceback()
#    3053         else:
#    3054             outflag = 0
#
# C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\interactiveshell.pyc in showtraceback(self, exc_tuple, filename, tb_offset, exception_only)
#    1849                     except Exception:
#    1850                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1851                                             value, tb, tb_offset=tb_offset)
#    1852
#    1853                     self._showtraceback(etype, value, stb)
#
# C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.pyc in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1238         self.tb = tb
#    1239         return FormattedTB.structured_traceback(
# -> 1240             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1241
#    1242
#
# C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.pyc in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1146             # Verbose modes need a full traceback
#    1147             return VerboseTB.structured_traceback(
# -> 1148                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1149             )
#    1150         else:
#
# C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.pyc in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#     998
#     999         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1000                                                                tb_offset)
#    1001
#    1002         colors = self.Colors  # just a shorthand + quicker name lookup
#
# C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.pyc in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#     949         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#     950
# --> 951         frames = self.format_records(records)
#     952         if records is None:
#     953             return ""
#
# C:\Users\Liz Contreras\Anaconda\lib\site-packages\IPython\core\ultratb.pyc in format_records(self, records)
#     722
#     723         abspath = os.path.abspath
# --> 724         for frame, file, lnum, func, lines, index in records:
#     725             #print '*** record:',file,lnum,func,lines,index  # dbg
#     726             if not file:
#
# TypeError: 'NoneType' object is not iterable

# %%
end_time = datetime.datetime.now()
print('Took {}s'.format(end_time - start_time))
make_graphic(W,dWords)

Resultados={}
for w, x, y in zip(dWords,W[:,0],W[:,1]):
    if not Resultados.has_key(w):
            Resultados[w]=x,y
            
resultado = sorted(Resultados.items(), key=operator.itemgetter(1))
resultado
